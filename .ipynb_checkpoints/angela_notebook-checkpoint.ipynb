# %%
## import all the things!!

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('tn.movie_budgets.csv.gz')

## checking dataframe
## questions to think about:
    ## what are the highest gross values for both domestic and worldwide?
    ## what's the ratio of production budget to gross?
    ## are there any values we can reasonably say won't help answer our questions?
        ## such as gross values that are too low and can be removed from our working dataset?
        

df.head(10)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5   6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 6   7  Apr 27, 2018                       Avengers: Infinity War
# 7   8  May 24, 2007   Pirates of the Caribbean: At Worldâs End
# 8   9  Nov 17, 2017                               Justice League
# 9  10   Nov 6, 2015                                      Spectre
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747
# 5      $306,000,000   $936,662,225  $2,053,311,220
# 6      $300,000,000   $678,815,482  $2,048,134,200
# 7      $300,000,000   $309,420,425    $963,420,425
# 8      $300,000,000   $229,024,295    $655,945,209
# 9      $300,000,000   $200,074,175    $879,620,923

# %%
## checking datatypes and checking for any missing values
## observations:
    ## 5782 total entries with no missing values
    ## release_date is object and should be changed to datetime
    ## production_budget, domestic_gross, & worldwide_gross are object datatypes & should be changed to int

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
## changing release_date datatype from object to datetime

df['release_date'] = pd.to_datetime(df['release_date'])


## changing object datatypes to integer

df['production_budget'] = df['production_budget'].str.replace( ',' , '')
df['production_budget'] = df['production_budget'].str.replace( '$' , '')
df['production_budget'] = pd.to_numeric(df['production_budget'])

df['domestic_gross'] = df['domestic_gross'].str.replace( ',' , '')
df['domestic_gross'] = df['domestic_gross'].str.replace( '$' , '')
df['domestic_gross'] = pd.to_numeric(df['domestic_gross'])

df['worldwide_gross'] = df['worldwide_gross'].str.replace( ',' , '')
df['worldwide_gross'] = df['worldwide_gross'].str.replace( '$' , '')
df['worldwide_gross'] = pd.to_numeric(df['worldwide_gross'])

# %%
## checking updated df

df.head(10)
# Out:
#    id release_date                                        movie  \
# 0   1   2009-12-18                                       Avatar
# 1   2   2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 2   3   2019-06-07                                 Dark Phoenix
# 3   4   2015-05-01                      Avengers: Age of Ultron
# 4   5   2017-12-15            Star Wars Ep. VIII: The Last Jedi
# 5   6   2015-12-18         Star Wars Ep. VII: The Force Awakens
# 6   7   2018-04-27                       Avengers: Infinity War
# 7   8   2007-05-24   Pirates of the Caribbean: At Worldâs End
# 8   9   2017-11-17                               Justice League
# 9  10   2015-11-06                                      Spectre
#
#    production_budget  domestic_gross  worldwide_gross
# 0          425000000       760507625       2776345279
# 1          410600000       241063875       1045663875
# 2          350000000        42762350        149762350
# 3          330600000       459005868       1403013963
# 4          317000000       620181382       1316721747
# 5          306000000       936662225       2053311220
# 6          300000000       678815482       2048134200
# 7          300000000       309420425        963420425
# 8          300000000       229024295        655945209
# 9          300000000       200074175        879620923

# %%
## checking updated df datatypes

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   datetime64[ns]
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   int64
#  4   domestic_gross     5782 non-null   int64
#  5   worldwide_gross    5782 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 271.2+ KB

# %%
## observations:
## there are a lot of domestic gross values that are 0 that can reasonably be removed from the working dataset
## we can probably also reasonably remove rows where the gross is "too low"

print(list(df['domestic_gross'].sort_values(ascending=False)))
# Out:
# [936662225, 760507625, 700059566, 678815482, 659363944, 652270625, 623279547, 620181382, 608581744, 533720947, 532177324, 504014165, 486295561, 474544677, 460998007, 459005868, 448139099, 441226247, 435110554, 426525952, 424668047, 423315812, 421785283, 417719760, 415004880, 412563408, 408992272, 408084349, 408010692, 404508916, 403706375, 402111870, 400738009, 395708305, 389813101, 381193157, 380529370, 380270577, 377845905, 376057266, 373524485, 370782930, 368384330, 368065385, 364001123, 363070709, 356461711, 353007020, 352390543, 350126372, 342548984, 341268248, 337135885, 336530303, 336045770, 335061807, 334201140, 334191110, 333172112, 330360194, 330151138, 327481748, 325100054, 324591735, 322719944, 319246193, 318604126, 317871467, 317101119, 315544750, 315058289, 312433331, 310676740, 309420425, 309205079, 306169255, 305411224, 304360277, 303003568, 302089278, 300531751, 296623634, 296131568, 293506292, 293004164, 292576195, 292324737, 292137260, 291710957, 291045518, 290271960, 290201752, 289423425, 285761243, 281723902, 281553689, 281287133, 279167575, 277322503, 274092705, 270620950, 270329045, 268488329, 267655011, 264624300, 262233381, 262030663, 261441092, 260044825, 260000000, 259746958, 258366855, 257784718, 257730019, 256393010, 255959475, 255119788, 254464305, 251513985, 251188924, 250863268, 250690539, 249757726, 248757044, 246734314, 245852179, 245439076, 244082982, 242704995, 242212467, 241688385, 241438208, 241407328, 238736787, 238679850, 237282182, 234770996, 234760478, 234362462, 234280354, 234037575, 233921534, 233632142, 232641920, 230347346, 229086679, 228778661, 228433663, 227969295, 227946274, 227471070, 226277068, 226164286, 225686079, 223808164, 222527828, 220159104, 219614612, 219195051, 218665740, 218080025, 217631306, 217581232, 217536138, 217350219, 217326974, 216648740, 216391482, 216335085, 216303339, 215434591, 215409889, 215288866, 214949694, 214030500, 213511408, 213117789, 212259762, 210614939, 210031325, 209726015, 209397903, 209218368, 209028679, 208545589, 206459076, 206445654, 206362140, 206040085, 205343774, 203464105, 202853933, 202359711, 202007640, 201578182, 201151353, 201091711, 200676069, 198680470, 198539855, 198351526, 198000317, 197171806, 196573705, 195330621, 195042377, 193595521, 192769854, 191796233, 191719337, 191204754, 190418803, 190173195, 190068280, 189412677, 188024361, 188017894, 187683805, 187224605, 187168425, 186848418, 186740799, 186336279, 184925486, 184296230, 184208842, 184031112, 183875760, 183637894, 183417150, 183135014, 182805123, 182618434, 182207973, 181813770, 181410615, 181166115, 181030624, 180981886, 180202163, 180174880, 180011740, 179883157, 179880271, 179800601, 178406268, 177784257, 177397510, 177243721, 177200000, 177002924, 176760185, 176654505, 176591618, 176484651, 176387405, 176087450, 176040665, 175750384, 175006930, 175003033, 174803506, 174532921, 174340174, 173840591, 173772767, 173585516, 173005002, 172956409, 172825435, 171958438, 171479930, 171243005, 171091819, 170708996, 170687518, 169705587, 169700110, 169607287, 169211718, 169100479, 168213584, 167780960, 167767189, 167500092, 167365000, 166225040, 166167230, 165493908, 165249063, 165092266, 164606800, 163958031, 163479795, 163214888, 163214286, 162994032, 162833635, 162805434, 162798565, 162586036, 162192920, 162001186, 161491646, 161412000, 161321843, 161197785, 160942139, 160791800, 159616327, 159581587, 159342015, 158340892, 158119460, 157299717, 157019771, 156645693, 155464351, 155385488, 155190832, 155064265, 155019340, 154696080, 154529439, 154112492, 153952592, 153707064, 153665036, 153636354, 153294164, 152647258, 152257509, 151101803, 150947895, 150415432, 150394119, 150357137, 150117807, 150086800, 149260504, 148809770, 148761765, 148478011, 148438600, 148415853, 148313048, 148213377, 148168459, 148095302, 146336178, 146282411, 145771527, 145096820, 145000989, 144833357, 144801023, 144731527, 144512310, 144156605, 144130063, 143619809, 143528619, 143495265, 143153 ...

# %%
## removing rows with domestic_gross < 20,000,000

df = df[df['domestic_gross'] > 20000000]

## we've reduced the number of entries to 2727

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2727 entries, 0 to 5745
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2727 non-null   int64
#  1   release_date       2727 non-null   datetime64[ns]
#  2   movie              2727 non-null   object
#  3   production_budget  2727 non-null   int64
#  4   domestic_gross     2727 non-null   int64
#  5   worldwide_gross    2727 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 149.1+ KB

# %%
## creating two new columns for domestic profit and worldwide profit
## removing rows with negative profits

df['domestic_profit'] = (df['domestic_gross'] - df['production_budget'])
df['worldwide_profit'] = (df['worldwide_gross'] - df['production_budget'])
df = df[(df['domestic_profit'] > 0) & (df['worldwide_profit'] > 0)]
df
# Out:
#       id release_date                                 movie  \
# 0      1   2009-12-18                                Avatar
# 3      4   2015-05-01               Avengers: Age of Ultron
# 4      5   2017-12-15     Star Wars Ep. VIII: The Last Jedi
# 5      6   2015-12-18  Star Wars Ep. VII: The Force Awakens
# 6      7   2018-04-27                Avengers: Infinity War
# ...   ..          ...                                   ...
# 5536  37   1978-10-17                             Halloween
# 5568  69   1981-05-01                        Graduation Day
# 5665  66   1974-10-18           The Texas Chainsaw Massacre
# 5679  80   2015-07-10                           The Gallows
# 5745  46   1972-06-30                           Deep Throat
#
#       production_budget  domestic_gross  worldwide_gross  domestic_profit  \
# 0             425000000       760507625       2776345279        335507625
# 3             330600000       459005868       1403013963        128405868
# 4             317000000       620181382       1316721747        303181382
# 5             306000000       936662225       2053311220        630662225
# 6             300000000       678815482       2048134200        378815482
# ...                 ...             ...              ...              ...
# 5536             325000        47000000         70000000         46675000
# 5568             250000        23894000         23894000         23644000
# 5665             140000        26572439         26572439         26432439
# 5679             100000        22764410         41656474         22664410
# 5745              25000        45000000         45000000         44975000
#
#       worldwide_profit
# 0           2351345279
# 3           1072413963
# 4            999721747
# 5           1747311220
# 6           1748134200
# ...                ...
# 5536          69675000
# 5568          23644000
# 5665          26432439
# 5679          41556474
# 5745          44975000
#
# [2010 rows x 8 columns]

# %%
## sort df by highest domestic profits

df_dp = df.sort_values(by=['domestic_profit'], ascending=False)
df_dp
# Out:
#       id release_date                                 movie  \
# 5      6   2015-12-18  Star Wars Ep. VII: The Force Awakens
# 41    42   2018-02-16                         Black Panther
# 42    43   1997-12-19                               Titanic
# 3464  65   1977-05-25          Star Wars Ep. IV: A New Hope
# 33    34   2015-06-12                        Jurassic World
# ...   ..          ...                                   ...
# 1134  35   2014-10-17                      The Book of Life
# 378   79   1996-06-21           The Hunchback of Notre Dame
# 503    4   2006-09-29                           Open Season
# 1135  36   1997-02-14                        Absolute Power
# 2240  41   1996-07-26                               Kingpin
#
#       production_budget  domestic_gross  worldwide_gross  domestic_profit  \
# 5             306000000       936662225       2053311220        630662225
# 41            200000000       700059566       1348258224        500059566
# 42            200000000       659363944       2208208395        459363944
# 3464           11000000       460998007        786598007        449998007
# 33            215000000       652270625       1648854864        437270625
# ...                 ...             ...              ...              ...
# 1134           50000000        50151543         97651543           151543
# 378           100000000       100138851        325500000           138851
# 503            85000000        85105259        191932158           105259
# 1135           50000000        50068310         50068310            68310
# 2240           25000000        25023424         32223424            23424
#
#       worldwide_profit
# 5           1747311220
# 41          1148258224
# 42          2008208395
# 3464         775598007
# 33          1433854864
# ...                ...
# 1134          47651543
# 378          225500000
# 503          106932158
# 1135             68310
# 2240           7223424
#
# [2010 rows x 8 columns]

# %%
## sort df by highest worldwide profits

df_wp = df.sort_values(by=['worldwide_profit'], ascending=False)
df_wp
# Out:
#       id release_date                                 movie  \
# 0      1   2009-12-18                                Avatar
# 42    43   1997-12-19                               Titanic
# 6      7   2018-04-27                Avengers: Infinity War
# 5      6   2015-12-18  Star Wars Ep. VII: The Force Awakens
# 33    34   2015-06-12                        Jurassic World
# ...   ..          ...                                   ...
# 1225  26   2001-08-13                                 K-PAX
# 2588  89   1990-10-19                    Quigley Down Under
# 2456  57   1996-12-20                   My Fellow Americans
# 2591  92   1998-10-30                              Vampires
# 1135  36   1997-02-14                        Absolute Power
#
#       production_budget  domestic_gross  worldwide_gross  domestic_profit  \
# 0             425000000       760507625       2776345279        335507625
# 42            200000000       659363944       2208208395        459363944
# 6             300000000       678815482       2048134200        378815482
# 5             306000000       936662225       2053311220        630662225
# 33            215000000       652270625       1648854864        437270625
# ...                 ...             ...              ...              ...
# 1225           48000000        50315140         50315140          2315140
# 2588           20000000        21413105         21413105          1413105
# 2456           21500000        22331846         22331846           831846
# 2591           20000000        20268825         20268825           268825
# 1135           50000000        50068310         50068310            68310
#
#       worldwide_profit
# 0           2351345279
# 42          2008208395
# 6           1748134200
# 5           1747311220
# 33          1433854864
# ...                ...
# 1225           2315140
# 2588           1413105
# 2456            831846
# 2591            268825
# 1135             68310
#
# [2010 rows x 8 columns]

# %%
## data visualization

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20,8))

x1 = df_dp['movie'][0:10]
y1 = df_dp['domestic_profit'][0:10]
ax1.bar(x1, y1)
ax1.set_title('Top 10 Movies with Highest Domestic Profits')
ax1.set_xlabel('Movies')
ax1.set_ylabel('Domestic Profits (in hundred millions)')
plt.xticks(rotation=20)

x2 = df_wp['movie'][0:10]
y2 = df_wp['worldwide_profit'][0:10]
ax2.bar(x2, y2)
ax2.set_title('Top 10 Movies with Highest Worldwide Profits')
ax2.set_xlabel('Movies')
ax2.set_ylabel('Worldwide Profits (in billions)')
plt.xticks(rotation=90);
