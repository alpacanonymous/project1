# %% [markdown]
# # Project 1 - Group 6
# ###### <font color='gray'>Authors: Aisha Baitemoriva-Othman, Adonis McQueen, Angela Kim, Deja Prade, James Kang</font>

# %%
## Import libraries ##
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
## Import datasets ##

# Aisha's datasets: Rotten Tomatoes
df_rt_movie_info = pd.read_csv('data/rt.movie_info.tsv.gz',sep='\t')
df_rt_reviews = pd.read_csv('data/rt.reviews.tsv.gz',sep='\t',encoding='latin1')

# Adonis's dataset: Box Office Mojo
df_gross = pd.read_csv("data/bom.movie_gross.csv.gz")

# Angela's dataset: The Numbers
mb = pd.read_csv('data/tn.movie_budgets.csv.gz')

# Deja's dataset: TMDB
movie_type = pd.read_csv('data/tmdb.movies.csv.gz')

# James's datasets: IMDB
title_ratings = pd.read_csv('data/imdb.title.ratings.csv.gz')
title_basics = pd.read_csv('data/imdb.title.basics.csv.gz')
title_akas = pd.read_csv('data/imdb.title.akas.csv.gz')

# %% [markdown]
# ### Questions
# <ul>
# <li>Which movies have the highest gross values?
# <li>What are the domestic and worldwide profits?
# <li>What is the trend of movie genres over time?
# <li>How has average movie runtime changed over time?
# </ul>

# %% [markdown]
# ### Angela's Data Analysis:

# %%
## Preliminary analysis
mb.head(10)
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# 5   6  Dec 18, 2015         Star Wars Ep. VII: The Force Awakens
# 6   7  Apr 27, 2018                       Avengers: Infinity War
# 7   8  May 24, 2007   Pirates of the Caribbean: At Worldâs End
# 8   9  Nov 17, 2017                               Justice League
# 9  10   Nov 6, 2015                                      Spectre
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747
# 5      $306,000,000   $936,662,225  $2,053,311,220
# 6      $300,000,000   $678,815,482  $2,048,134,200
# 7      $300,000,000   $309,420,425    $963,420,425
# 8      $300,000,000   $229,024,295    $655,945,209
# 9      $300,000,000   $200,074,175    $879,620,923

# %%
## Checking datatypes and looking for any missing values
mb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# **Observations and Insights:**
# <ul>
# <li>There are 5782 total entries with 0 missing values.
# <li>The release date column is the object datatype and should be changed to the datetime datatype.
# <li>The production budget, domestic gross, and worldwide gross columns are also object datatypes and should be changed to integer.
# </ul>

# %%
## Changing release_date to datetime
mb['release_date'] = pd.to_datetime(mb['release_date'])

## Changing production_budget, domestic_gross, and worldwide_gross to integer

mb['production_budget'] = mb['production_budget'].str.replace( ',' , '')
mb['production_budget'] = mb['production_budget'].str.replace( '$' , '')
mb['production_budget'] = pd.to_numeric(mb['production_budget'])

mb['domestic_gross'] = mb['domestic_gross'].str.replace( ',' , '')
mb['domestic_gross'] = mb['domestic_gross'].str.replace( '$' , '')
mb['domestic_gross'] = pd.to_numeric(mb['domestic_gross'])

mb['worldwide_gross'] = mb['worldwide_gross'].str.replace( ',' , '')
mb['worldwide_gross'] = mb['worldwide_gross'].str.replace( '$' , '')
mb['worldwide_gross'] = pd.to_numeric(mb['worldwide_gross'])


## Check that all changes have been correctly made
mb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   datetime64[ns]
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   int64
#  4   domestic_gross     5782 non-null   int64
#  5   worldwide_gross    5782 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 271.2+ KB

# %%
## Remove rows with release_date before 2010 to focus on analyzing data from the most recent decade

mb = mb[(mb['release_date']) >= '2010-01-01']

mb.head(30)
# Out:
#     id release_date                                             movie  \
# 1    2   2011-05-20       Pirates of the Caribbean: On Stranger Tides
# 2    3   2019-06-07                                      Dark Phoenix
# 3    4   2015-05-01                           Avengers: Age of Ultron
# 4    5   2017-12-15                 Star Wars Ep. VIII: The Last Jedi
# 5    6   2015-12-18              Star Wars Ep. VII: The Force Awakens
# 6    7   2018-04-27                            Avengers: Infinity War
# 8    9   2017-11-17                                    Justice League
# 9   10   2015-11-06                                           Spectre
# 10  11   2012-07-20                             The Dark Knight Rises
# 11  12   2018-05-25                           Solo: A Star Wars Story
# 12  13   2013-07-02                                   The Lone Ranger
# 13  14   2012-03-09                                       John Carter
# 14  15   2010-11-24                                           Tangled
# 16  17   2016-05-06                        Captain America: Civil War
# 17  18   2016-03-25                Batman v Superman: Dawn of Justice
# 18  19   2012-12-14                 The Hobbit: An Unexpected Journey
# 20  21   2013-12-13               The Hobbit: The Desolation of Smaug
# 21  22   2014-12-17         The Hobbit: The Battle of the Five Armies
# 22  23   2017-04-14                           The Fate of the Furious
# 24  25   2017-05-26  Pirates of the Caribbean: Dead Men Tell No Tales
# 26  27   2012-05-04                                      The Avengers
# 28  29   2013-06-14                                      Man of Steel
# 30  31   2012-07-03                            The Amazing Spider-Man
# 31  32   2012-05-18                                        Battleship
# 32  33   2017-06-21                     Transformers: The Last Knight
# 33  34   2015-06-12                                    Jurassic World
# 34  35   2012-05-25                                    Men in Black 3
# 36  37   2014-06-27                   Transformers: Age of Extinction
# 38  39   2010-05-14                                        Robin Hood
# 41  42   2018-02-16                                     Black Panther
#
#     production_budget  domestic_gross  worldwide_gross
# 1           410600000       241063875       1045663875
# 2           350000000        42762350        149762350
# 3           330600000       459005868       1403013963
# 4           317000000       620181382       1316721747
# 5           306000000       936662225       2053311220
# 6           300000000       678815482       2048134200
# 8           300000000       229024295        655945209
# 9           300000000       200074175        879620923
# 10          275000000       448139099       1084439099
# 11          275000000       213767512        393151347
# 12          275000000        89302115        260002115
# 13          275000000        73058679        282778100
# 14          260000000       200821936        586477240
# 16          250000000       408084349       1140069413
# 17          250000000       330360194        867500281
# 18          250000000       303003568       1017003568
# 20          250000000       258366855        960366855
# 21          250000000       255119788        945577621
# 22          250000000       225764765       1234846267
# 24          230000000       172558876        788241137
# 26          225000000       623279547       1517935897
# 28          225000000       291045518        667999518
# 30          220000000       262030663        757890267
# 31          220000000        65233400        313477717
# 32          217000000       130168683        602893340
# 33          215000000       652270625       1648854864
# 34          215000000       179020854        654213485
# 36          210000000       245439076       1104039076
# 38          210000000       105487148        322459006
# 41          200000000       700059566       1348258224

# %%
mb.tail(30)
# Out:
#       id release_date                              movie  production_budget  \
# 5717  18   2010-11-12                     Tiny Furniture              50000
# 5719  20   2015-07-31                           Counting              50000
# 5721  22   2014-02-14                 Down and Dangerous              50000
# 5723  24   2015-08-04                      Bending Steel              50000
# 5724  25   2015-09-01                     Run, Hide, Die              50000
# 5725  26   2014-12-31               The Image Revolution              50000
# 5726  27   2013-10-25                       A True Story              45000
# 5728  29   2013-06-21              This Is Martin Bonner              42000
# 5730  31   2010-03-12                 The Exploding Girl              40000
# 5731  32   2011-02-11                     Raymond Did It              40000
# 5732  33   2012-03-31                    Foreign Letters              40000
# 5734  35   2013-10-25  Her Cry: La Llorona Investigation              35000
# 5735  36   2014-12-31                         Happy 40th              35000
# 5737  38   2016-03-18                             Krisha              30000
# 5740  41   2010-10-15                       Down Terrace              30000
# 5741  42   2013-12-31                         Paraphobia              30000
# 5744  45   2017-01-27                              Emily              27000
# 5748  49   2015-09-01                             Exeter              25000
# 5750  51   2015-04-21                                Ten              25000
# 5751  52   2015-12-01                        Dutch Kills              25000
# 5753  54   2014-12-31                          Dry Spell              22000
# 5755  56   2013-01-04           All Superheroes Must Die              20000
# 5756  57   2015-04-21                      The Front Man              20000
# 5758  59   2011-11-25                         The Ridges              17300
# 5760  61   2010-04-02                   Breaking Upwards              15000
# 5761  62   2014-12-31               Stories of Our Lives              15000
# 5771  72   2015-05-19                   Family Motocross              10000
# 5772  73   2012-01-13                          Newlyweds               9000
# 5777  78   2018-12-31                             Red 11               7000
# 5780  81   2015-09-29               A Plague So Pleasant               1400
#
#       domestic_gross  worldwide_gross
# 5717          391674           424149
# 5719            8374             8374
# 5721               0                0
# 5723               0                0
# 5724               0                0
# 5725               0                0
# 5726               0                0
# 5728               0                0
# 5730           25572            25572
# 5731            3632             3632
# 5732               0                0
# 5734               0                0
# 5735               0                0
# 5737          144822           144822
# 5740            9812             9812
# 5741               0                0
# 5744            3547             3547
# 5748               0           489792
# 5750               0                0
# 5751               0                0
# 5753               0                0
# 5755               0                0
# 5756               0                0
# 5758               0                0
# 5760          115592           115592
# 5761               0                0
# 5771               0                0
# 5772            4584             4584
# 5777               0                0
# 5780               0                0

# %% [markdown]
# **Observations & Insights:**
# <ul>
# <li>There are a lot of gross values that are 0. They also tend to correlate with movies with very small production budgets.
# <li>Upon investigation, these films are usually independently made and don't apply to a large corporation like Microsoft.
# </ul>

# %%
## Create two new columns for domestic profit and worldwide profit
## Remove rows with negative profits

mb['domestic_profit'] = (mb['domestic_gross'] - mb['production_budget'])
mb['worldwide_profit'] = (mb['worldwide_gross'] - mb['production_budget'])
mb.head(30)
# Out:
#     id release_date                                             movie  \
# 1    2   2011-05-20       Pirates of the Caribbean: On Stranger Tides
# 2    3   2019-06-07                                      Dark Phoenix
# 3    4   2015-05-01                           Avengers: Age of Ultron
# 4    5   2017-12-15                 Star Wars Ep. VIII: The Last Jedi
# 5    6   2015-12-18              Star Wars Ep. VII: The Force Awakens
# 6    7   2018-04-27                            Avengers: Infinity War
# 8    9   2017-11-17                                    Justice League
# 9   10   2015-11-06                                           Spectre
# 10  11   2012-07-20                             The Dark Knight Rises
# 11  12   2018-05-25                           Solo: A Star Wars Story
# 12  13   2013-07-02                                   The Lone Ranger
# 13  14   2012-03-09                                       John Carter
# 14  15   2010-11-24                                           Tangled
# 16  17   2016-05-06                        Captain America: Civil War
# 17  18   2016-03-25                Batman v Superman: Dawn of Justice
# 18  19   2012-12-14                 The Hobbit: An Unexpected Journey
# 20  21   2013-12-13               The Hobbit: The Desolation of Smaug
# 21  22   2014-12-17         The Hobbit: The Battle of the Five Armies
# 22  23   2017-04-14                           The Fate of the Furious
# 24  25   2017-05-26  Pirates of the Caribbean: Dead Men Tell No Tales
# 26  27   2012-05-04                                      The Avengers
# 28  29   2013-06-14                                      Man of Steel
# 30  31   2012-07-03                            The Amazing Spider-Man
# 31  32   2012-05-18                                        Battleship
# 32  33   2017-06-21                     Transformers: The Last Knight
# 33  34   2015-06-12                                    Jurassic World
# 34  35   2012-05-25                                    Men in Black 3
# 36  37   2014-06-27                   Transformers: Age of Extinction
# 38  39   2010-05-14                                        Robin Hood
# 41  42   2018-02-16                                     Black Panther
#
#     production_budget  domestic_gross  worldwide_gross  domestic_profit  \
# 1           410600000       241063875       1045663875       -169536125
# 2           350000000        42762350        149762350       -307237650
# 3           330600000       459005868       1403013963        128405868
# 4           317000000       620181382       1316721747        303181382
# 5           306000000       936662225       2053311220        630662225
# 6           300000000       678815482       2048134200        378815482
# 8           300000000       229024295        655945209        -70975705
# 9           300000000       200074175        879620923        -99925825
# 10          275000000       448139099       1084439099        173139099
# 11          275000000       213767512        393151347        -61232488
# 12          275000000        89302115        260002115       -185697885
# 13          275000000        73058679        282778100       -201941321
# 14          260000000       200821936        586477240        -59178064
# 16          250000000       408084349       1140069413        158084349
# 17          250000000       330360194        867500281         80360194
# 18          250000000       303003568       1017003568         53003568
# 20          250000000       258366855        960366855          8366855
# 21          250000000       255119788        945577621          5119788
# 22          250000000       225764765       1234846267        -24235235
# 24          230000000       172558876        788241137        -57441124
# 26          225000000       623279547       1517935897        398279547
# 28          225000000       291045518        667999518         66045518
# 30          220000000       262030663        757890267         42030663
# 31          220000000        65233400        313477717       -154766600
# 32          217000000       130168683        602893340        -86831317
# 33          215000000       652270625       1648854864        437270625
# 34          215000000       179020854        654213485        -35979146
# 36          210000000       245439076       1104039076         35439076
# 38          210000000       105487148        322459006       -104512852
# 41          200000000       700059566       1348258224        500059566
#
#     worldwide_profit
# 1          635063875
# 2         -200237650
# 3         1072413963
# 4          999721747
# 5         1747311220
# 6         1748134200
# 8          355945209
# 9          579620923
# 10         809439099
# 11         118151347
# 12         -14997885
# 13           7778100
# 14         326477240
# 16         890069413
# 17         617500281
# 18         767003568
# 20         710366855
# 21         695577621
# 22         984846267
# 24         558241137
# 26        1292935897
# 28         442999518
# 30         537890267
# 31          93477717
# 32         385893340
# 33        1433854864
# 34         439213485
# 36         894039076
# 38         112459006
# 41        1148258224

# %% [markdown]
# **Observations & Insights:**
# <ul>
# <li>There are films that are box office bombs such as Dark Phoenix, The Lone Ranger, and Pirates of the Caribbean: On Strangers Tides. Their production budgets overshadowed their box office revenues.
# </ul>

# %%
## Sort by highest domestic profits

mb_dp = mb.sort_values(by=['domestic_profit'], ascending=False)
mb_dp.reset_index(inplace=True)
mb_dp.head(30)
# Out:
#     index  id release_date                                          movie  \
# 0       5   6   2015-12-18           Star Wars Ep. VII: The Force Awakens
# 1      41  42   2018-02-16                                  Black Panther
# 2      33  34   2015-06-12                                 Jurassic World
# 3      43  44   2018-06-15                                  Incredibles 2
# 4      26  27   2012-05-04                                   The Avengers
# 5       6   7   2018-04-27                         Avengers: Infinity War
# 6     134  35   2017-03-17                           Beauty and the Beast
# 7      44  45   2016-12-16                   Rogue One: A Star Wars Story
# 8     537  38   2012-03-23                               The Hunger Games
# 9     437  38   2017-12-20                 Jumanji: Welcome to the Jungle
# 10    955  56   2016-02-12                                       Deadpool
# 11      4   5   2017-12-15              Star Wars Ep. VIII: The Last Jedi
# 12    237  38   2013-11-22                The Hunger Games: Catching Fire
# 13    625  26   2016-07-08                        The Secret Life of Pets
# 14   1623  24   2017-09-08                                             It
# 15    956  57   2014-12-25                                American Sniper
# 16    621  22   2013-07-03                                Despicable Me 2
# 17     45  46   2016-06-17                                   Finding Dory
# 18    154  55   2017-06-02                                   Wonder Woman
# 19    672  73   2015-07-10                                        Minions
# 20    260  61   2011-07-15  Harry Potter and the Deathly Hallows: Part II
# 21     95  96   2019-03-08                                 Captain Marvel
# 22    155  56   2013-11-22                                         Frozen
# 23    112  13   2018-06-22                 Jurassic World: Fallen Kingdom
# 24    752  53   2010-06-30                     The Twilight Saga: Eclipse
# 25     46  47   2010-06-18                                    Toy Story 3
# 26    314  15   2018-05-18                                     Deadpool 2
# 27    261  62   2014-11-21          The Hunger Games: Mockingjay - Part 1
# 28     47  48   2013-05-03                                     Iron Man 3
# 29    843  44   2014-02-07                                 The Lego Movie
#
#     production_budget  domestic_gross  worldwide_gross  domestic_profit  \
# 0           306000000       936662225       2053311220        630662225
# 1           200000000       700059566       1348258224        500059566
# 2           215000000       652270625       1648854864        437270625
# 3           200000000       608581744       1242520711        408581744
# 4           225000000       623279547       1517935897        398279547
# 5           300000000       678815482       2048134200        378815482
# 6           160000000       504014165       1259199706        344014165
# 7           200000000       532177324       1049102856        332177324
# 8            80000000       408010692        677923379        328010692
# 9            90000000       404508916        964496193        314508916
# 10           58000000       363070709        801025593        305070709
# 11          317000000       620181382       1316721747        303181382
# 12          130000000       424668047        864868047        294668047
# 13           75000000       368384330        886750534        293384330
# 14           35000000       327481748        697457969        292481748
# 15           58000000       350126372        547326372        292126372
# 16           76000000       368065385        975216835        292065385
# 17          200000000       486295561       1021215193        286295561
# 18          150000000       412563408        821133378        262563408
# 19           74000000       336045770       1160336173        262045770
# 20          125000000       381193157       1341693157        256193157
# 21          175000000       426525952       1123061550        251525952
# 22          150000000       400738009       1272469910        250738009
# 23          170000000       417719760       1305772799        247719760
# 24           68000000       300531751        706102828        232531751
# 25          200000000       415004880       1068879522        215004880
# 26          110000000       324591735        786680557        214591735
# 27          125000000       337135885        766575131        212135885
# 28          200000000       408992272       1215392272        208992272
# 29           60000000       257784718        457729388        197784718
#
#     worldwide_profit
# 0         1747311220
# 1         1148258224
# 2         1433854864
# 3         1042520711
# 4         1292935897
# 5         1748134200
# 6         1099199706
# 7          849102856
# 8          597923379
# 9          874496193
# 10         743025593
# 11         999721747
# 12         734868047
# 13         811750534
# 14         662457969
# 15         489326372
# 16         899216835
# 17         821215193
# 18         671133378
# 19        1086336173
# 20        1216693157
# 21         948061550
# 22        1122469910
# 23        1135772799
# 24         638102828
# 25         868879522
# 26         676680557
# 27         641575131
# 28        1015392272
# 29         397729388

# %%
## Sort by highest worldwide profits

mb_wp = mb.sort_values(by=['worldwide_profit'], ascending=False)
mb_wp.reset_index(inplace=True)
mb_wp.head(30)
# Out:
#     index  id release_date                                          movie  \
# 0       6   7   2018-04-27                         Avengers: Infinity War
# 1       5   6   2015-12-18           Star Wars Ep. VII: The Force Awakens
# 2      33  34   2015-06-12                                 Jurassic World
# 3      66  67   2015-04-03                                      Furious 7
# 4      26  27   2012-05-04                                   The Avengers
# 5     260  61   2011-07-15  Harry Potter and the Deathly Hallows: Part II
# 6      41  42   2018-02-16                                  Black Panther
# 7     112  13   2018-06-22                 Jurassic World: Fallen Kingdom
# 8     155  56   2013-11-22                                         Frozen
# 9     134  35   2017-03-17                           Beauty and the Beast
# 10    672  73   2015-07-10                                        Minions
# 11      3   4   2015-05-01                        Avengers: Age of Ultron
# 12     43  44   2018-06-15                                  Incredibles 2
# 13     47  48   2013-05-03                                     Iron Man 3
# 14      4   5   2017-12-15              Star Wars Ep. VIII: The Last Jedi
# 15    135  36   2018-12-21                                        Aquaman
# 16     22  23   2017-04-14                        The Fate of the Furious
# 17    629  30   2017-06-30                                Despicable Me 3
# 18     95  96   2019-03-08                                 Captain Marvel
# 19     63  64   2011-06-29                 Transformers: Dark of the Moon
# 20     51  52   2012-11-08                                        Skyfall
# 21    621  22   2013-07-03                                Despicable Me 2
# 22     36  37   2014-06-27                Transformers: Age of Extinction
# 23     16  17   2016-05-06                     Captain America: Civil War
# 24    437  38   2017-12-20                 Jumanji: Welcome to the Jungle
# 25    156  57   2016-03-04                                       Zootopia
# 26     46  47   2010-06-18                                    Toy Story 3
# 27     44  45   2016-12-16                   Rogue One: A Star Wars Story
# 28    983  84   2018-11-02                              Bohemian Rhapsody
# 29    263  64   2010-11-19   Harry Potter and the Deathly Hallows: Part I
#
#     production_budget  domestic_gross  worldwide_gross  domestic_profit  \
# 0           300000000       678815482       2048134200        378815482
# 1           306000000       936662225       2053311220        630662225
# 2           215000000       652270625       1648854864        437270625
# 3           190000000       353007020       1518722794        163007020
# 4           225000000       623279547       1517935897        398279547
# 5           125000000       381193157       1341693157        256193157
# 6           200000000       700059566       1348258224        500059566
# 7           170000000       417719760       1305772799        247719760
# 8           150000000       400738009       1272469910        250738009
# 9           160000000       504014165       1259199706        344014165
# 10           74000000       336045770       1160336173        262045770
# 11          330600000       459005868       1403013963        128405868
# 12          200000000       608581744       1242520711        408581744
# 13          200000000       408992272       1215392272        208992272
# 14          317000000       620181382       1316721747        303181382
# 15          160000000       335061807       1146894640        175061807
# 16          250000000       225764765       1234846267        -24235235
# 17           75000000       264624300       1034727750        189624300
# 18          175000000       426525952       1123061550        251525952
# 19          195000000       352390543       1123790543        157390543
# 20          200000000       304360277       1110526981        104360277
# 21           76000000       368065385        975216835        292065385
# 22          210000000       245439076       1104039076         35439076
# 23          250000000       408084349       1140069413        158084349
# 24           90000000       404508916        964496193        314508916
# 25          150000000       341268248       1019429616        191268248
# 26          200000000       415004880       1068879522        215004880
# 27          200000000       532177324       1049102856        332177324
# 28           55000000       216303339        894985342        161303339
# 29          125000000       296131568        960431568        171131568
#
#     worldwide_profit
# 0         1748134200
# 1         1747311220
# 2         1433854864
# 3         1328722794
# 4         1292935897
# 5         1216693157
# 6         1148258224
# 7         1135772799
# 8         1122469910
# 9         1099199706
# 10        1086336173
# 11        1072413963
# 12        1042520711
# 13        1015392272
# 14         999721747
# 15         986894640
# 16         984846267
# 17         959727750
# 18         948061550
# 19         928790543
# 20         910526981
# 21         899216835
# 22         894039076
# 23         890069413
# 24         874496193
# 25         869429616
# 26         868879522
# 27         849102856
# 28         839985342
# 29         835431568

# %%
## Bar chart of Top 20 Movies with Highest Domestic Profits

fig, ax = plt.subplots(figsize=(10,5))

x1 = mb_dp['movie'][0:20]
y1 = mb_dp['domestic_profit'][0:20]

ax = sns.barplot(x=y1, y=x1, palette='flare_r')
ax.set(xlabel='Domestic Profits (in millions)', ylabel='Movies', title='Top 20 Movies with Highest Domestic Profits');

# %%
## Bar chart of Top 20 Movies with Highest Worldwide Profits

fig, ax = plt.subplots(figsize=(10, 5))

x2 = mb_wp['movie'][0:20]
y2 = mb_wp['worldwide_profit'][0:20]

ax = sns.barplot(x=y2, y=x2, palette='flare_r')
ax.set(xlabel='Worldwide Profits (in billions)', ylabel='Movies', title='Top 20 Movies with Highest Worldwide Profits');

# %% [markdown]
# #### <b>Observations & Insights:</b>
# <ul>
# <li>The 10 movies with highest domestic profits from 2010-mid2019 are <b><i>Star Wars Ep. VII: The Force Awakens, Black Panther, Jurassic World, Incredibles 2, The Avengers, Avengers: Infinity War, Beauty and the Beast, Rogue One: A Star Wars Story, The Hunger Games, and Jumanji: Welcome to the Jungle.</i></b>
# <li>The 10 movies with highest worldwide profits from 2010-mid2019 are <b><i>Avengers: Infinity War, Star Wars Ep. VII: The Force Awakens, Jurassic World, Furious 7, The Avengers, Harry Potter and the Deathly Hallows: Part II, Black Panther, Jurassic World: Fallen Kingdom, Frozen, and Beauty and the Beast.</i></b>
# <li>The most frequently occuring genres of the top 20 films are <b><i>Sci-fi, Action, Adventure, Animation, and Superhero.</i></b>
# <li>The majority of these films are part of the <b><i>Marvel</i></b> or <b><i>Star Wars</i></b> franchises.
# <li>There has also been a huge focus on revitalizing or reimagining classics such as <b><i>Jurassic Park, James Bond, and Jumanji.</i></b>
# <li>Many financially successful films are sequels such as <b><i>Star Wars Ep. VII, Avengers: Infinity War, Furious 7, Harry Potter and the Deathly Hallows: Parts I & II, and Incredibles 2</b></i>
# </ul>

# %% [markdown]
# ### Aisha's Data Analysis:

# %%
df_rt_movie_info.head(3)
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
#
#                          writer  theater_date      dvd_date currency  \
# 0                Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN

# %%
df_rt_movie_info.shape
# Out:
# (1560, 12)

# %%
# removing the month and day from the theater_date and create a new column with just the year of the release date
df_rt_movie_info['new_theater_date'] = df_rt_movie_info.theater_date.str[-4:]

# %%
# convert the values in the 'new_theater_date' column from strings to integers
df_rt_movie_info['new_theater_date'] = df_rt_movie_info['new_theater_date'].apply(pd.to_numeric)

# %%
df_rt_movie_info.head(3)
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
#
#                          writer  theater_date      dvd_date currency  \
# 0                Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1  David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
#
#   box_office      runtime             studio  new_theater_date
# 0        NaN  104 minutes                NaN            1971.0
# 1    600,000  108 minutes  Entertainment One            2012.0
# 2        NaN  116 minutes                NaN            1996.0

# %%
# there are 494 out of 1560 rows that have a missing studio value

df_rt_movie_info['studio'].isna().value_counts()
# Out:
# True     1066
# False     494
# Name: studio, dtype: int64

# %%
# all the studios listed
df_rt_movie_info['studio'].value_counts().head()
# Out:
# Universal Pictures        35
# Paramount Pictures        27
# 20th Century Fox          26
# Sony Pictures Classics    22
# Warner Bros. Pictures     21
# Name: studio, dtype: int64

# %%
df_rt_reviews.head(10)
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
# 5   3  ... Cronenberg's Cosmopolis expresses somethin...    NaN   fresh
# 6   3  Quickly grows repetitive and tiresome, meander...      C  rotten
# 7   3  Cronenberg is not a director to be daunted by ...    2/5  rotten
# 8   3  Cronenberg's cold, exacting precision and emot...    NaN   fresh
# 9   3  Over and above its topical urgency or the bit ...    NaN   fresh
#
#             critic  top_critic           publisher                date
# 0       PJ Nabarro           0     Patrick Nabarro   November 10, 2018
# 1   Annalee Newitz           0             io9.com        May 23, 2018
# 2     Sean Axmaker           0    Stream on Demand     January 4, 2018
# 3    Daniel Kasman           0                MUBI   November 16, 2017
# 4              NaN           0        Cinema Scope    October 12, 2017
# 5  Michelle Orange           0    Capital New York  September 11, 2017
# 6   Eric D. Snider           0     EricDSnider.com       July 17, 2013
# 7     Matt Kelemen           0  Las Vegas CityLife      April 21, 2013
# 8     Sean Axmaker           0       Parallax View      March 24, 2013
# 9     Kong Rithdee           0        Bangkok Post       March 4, 2013

# %%
df_rt_reviews[df_rt_reviews['rating'].isna()]
# Out:
#          id                                             review rating   fresh  \
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# 5         3  ... Cronenberg's Cosmopolis expresses somethin...    NaN   fresh
# ...     ...                                                ...    ...     ...
# 54409  2000  A lightweight, uneven action comedy that freel...    NaN  rotten
# 54417  2000  The funny thing is, I didn't mind all this con...    NaN   fresh
# 54425  2000  Despite Besson's high-profile name being Wasab...    NaN   fresh
# 54426  2000  The film lapses too often into sugary sentimen...    NaN  rotten
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
#
#                 critic  top_critic                   publisher  \
# 1       Annalee Newitz           0                     io9.com
# 2         Sean Axmaker           0            Stream on Demand
# 3        Daniel Kasman           0                        MUBI
# 4                  NaN           0                Cinema Scope
# 5      Michelle Orange           0            Capital New York
# ...                ...         ...                         ...
# 54409     Daniel Eagan           0  Film Journal International
# 54417    Andrew Sarris           1                    Observer
# 54425       Andy Klein           0                   New Times
# 54426     Paul Malcolm           1                 L.A. Weekly
# 54427    Laura Sinagra           1               Village Voice
#
#                      date
# 1            May 23, 2018
# 2         January 4, 2018
# 3       November 16, 2017
# 4        October 12, 2017
# 5      September 11, 2017
# ...                   ...
# 54409     October 5, 2002
# 54417     October 2, 2002
# 54425  September 26, 2002
# 54426  September 26, 2002
# 54427  September 24, 2002
#
# [13517 rows x 8 columns]

# %%
#split the "rating" column into two separate columns, separating them in "/" if the rating is not a letter
df_rt_reviews[['fn','sn']] = df_rt_reviews['rating'].str.split('/',expand=True)

# %%
df_rt_reviews.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date   fn   sn
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018    3    5
# 1  Annalee Newitz           0           io9.com       May 23, 2018  NaN  NaN
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018  NaN  NaN
# 3   Daniel Kasman           0              MUBI  November 16, 2017  NaN  NaN
# 4             NaN           0      Cinema Scope   October 12, 2017  NaN  NaN

# %%
# converting all string values in the 'fn' and 'sn' columns into numeric values
df_rt_reviews['fn'] = df_rt_reviews['fn'].apply(pd.to_numeric)
df_rt_reviews['sn'] = df_rt_reviews['sn'].apply(pd.to_numeric)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "C"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-b7cdd9804d89> in <module>
#       1 # converting all string values in the 'fn' and 'sn' columns into numeric values
# ----> 2 df_rt_reviews['fn'] = df_rt_reviews['fn'].apply(pd.to_numeric)
#       3 df_rt_reviews['sn'] = df_rt_reviews['sn'].apply(pd.to_numeric)
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     150         coerce_numeric = errors not in ("ignore", "raise")
#     151         try:
# --> 152             values = lib.maybe_convert_numeric(
#     153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "C" at position 0

# %%
df_rt_reviews['new_rating'] = df_rt_reviews.apply(lambda row: row.fn/row.sn, axis=1)

# %%
# delete rows that have a new_rating value higher than 1
df_rt_reviews = df_rt_reviews[df_rt_reviews.new_rating <=1]

# %%
df_rt_reviews.head()

# %%
#creating a new dataset with only 'id' and 'new_rating' columns of the 'df_rt_reviews' dataset
# so we can merge it later on with the 'df_rt_movie_info' dataset.
new_rt_reviews = pd.DataFrame(zip(df_rt_reviews.id, df_rt_reviews.new_rating))

# %%
# renaming the columns back into original names
new_rt_reviews.rename(columns={0: 'id', 1: 'rating'}, inplace=True)

# %%
new_rt_reviews.head()

# %%
df_rt_movie_info.head()

# %%
new_rt_movie_info= pd.DataFrame(zip(df_rt_movie_info.id, df_rt_movie_info.genre,df_rt_movie_info.runtime))

# %%
new_rt_movie_info.head()

# %%
# renaming the columns back into original names
new_rt_movie_info.rename(columns={0: 'id', 1: 'genres',2: 'runtime'}, inplace=True)

# %%
new_rt_movie_info.head()

# %%
# converting the 'runtime' column's strings values into floats
merged_datasets['runtime'] = pd.to_numeric(merged_datasets['runtime'])

# %%
merged_datasets.info()

# %%
merged_datasets['genres'].value_counts()
# the value count of movies by genre. The last four genre categories are too low in numbers compared to
# other movie genres
# We think it is best to remove them from our dataset

# %%
# creating a list of genres that are not statistically significant
not_significant_genres_list = ['Anime and Manga','Gay and Lesbian','Cult Movies','Faith and Spirituality','Television','Sports and Fitness','Documentary','Western','Special Interest']

# %%
# deleting the not statistically insignificant genres from the dataset and creating a new dataset without those genres
new_merged_datasets = merged_datasets[~merged_datasets.genres.isin(not_significant_genres_list)]

# %%
# finding the mean of runtime for each genre
average_runtime_per_genre = new_merged_datasets.groupby('genres', as_index=False)['runtime'].mean()
average_runtime_per_genre

# %%
# finding the mean of the ratings for each genre
average_rating_per_genre = new_merged_datasets.groupby('genres', as_index=False)['rating'].mean()
average_rating_per_genre

# %%
fig, ax11 = plt.subplots(figsize = (20,8))
x11 = average_rating_per_genre['genres']
y11 = average_rating_per_genre['mean_rating']
ax11.bar(x1,y1)
ax11.set_title('average rating per genre')
ax11.set_xlabel('genres')
ax11.set_ylabel('average rating')
plt.xticks(rotation = 45)

# %%
# The 4 genres that have the highest average ratings: 'Romance', 'Art House and International', 'Drama',
#  and 'Mystery and Suspense'

# %%
# creating a list of the four genres with the highest rating
four_genres_list = ['Romance','Art House and International','Drama','Mystery and Suspense']

# %%
# creating a dataset with only the four genres with the highest ratings
highest_rating_genres_dataset = merged_datasets[merged_datasets.genres.isin(four_genres_list)]

# %%
highest_rating_genres_dataset['genres'].value_counts()

# %%
# the mean of runtime for the four highest rating genres
highest_rating_genres_dataset['runtime'].mean()

# %%
# standard deviation from the mean for the four highest rating genres
highest_rating_genres_dataset['runtime'].std()

# %%
# getting an average runtime for each of the four highest rating genres
avg_runtime_high_rating_genres = highest_rating_genres_dataset.groupby('genres', as_index=False)['runtime'].mean()

# %%
# renaming the 'runtime' column of the new dataset into the "mean_runtime" 
avg_runtime_high_rating_genres.rename(columns={'runtime': 'mean_runtime'}, inplace=True)

# %%
avg_runtime_high_rating_genres

# %%
fig, ax22 = plt.subplots(figsize = (12,6))
x22 = avg_runtime_high_rating_genres['genres']
y22 = avg_runtime_high_rating_genres['mean_runtime']
ax22.bar(x2,y2)
ax22.set_title('average runtime per genre')
ax22.set_xlabel('genres')
ax22.set_ylabel('average rating')
plt.xticks(rotation = 45);

# %% [markdown]
# ### Adonis's Data Analysis

# %%
df_gross.head()

# %%
#find null values
df_gross['domestic_gross'].isnull().value_counts()

# %%
df_gross['foreign_gross'].isnull().value_counts()

# %%
df_gross.info()

# %%
#remove commas from values, convert to numeric
df_gross['foreign_gross'] = df_gross['foreign_gross'].str.replace(',', '')
df_gross['foreign_gross'] = pd.to_numeric(df_gross['foreign_gross'])
df_gross['foreign_gross'].head()

# %%
#remove null values from columns
df_gross.dropna(subset=['studio', 'domestic_gross', 'foreign_gross'], inplace=True)
df_gross.shape

# %%
#verification of null value deletion
df_gross.info()

# %%
#top ten studios with the most movies
df_gross['studio'].value_counts()[:10]

# %%
x = list(df_gross['studio'].value_counts()[:10].index)
x

# %%
#top 10 studios domestic gross
dfm2 = df_gross.groupby(['studio']).domestic_gross.sum().reset_index().sort_values(by='domestic_gross', ascending=False)
d = dfm2[dfm2['studio'].isin(x)]

# %%
#total gross for each film
df_gross['total_gross'] = df_gross['domestic_gross'] + df_gross['foreign_gross']
df_gross.head()

# %%
#sorting on domestic gross
f = df_gross.sort_values(by='domestic_gross', ascending=False)

f.head()

# %% [markdown]
# ### Some foreign gross values seem wrong for blockbuster films. Are there more?

# %%
#sorting df on foreign gross
g = df_gross.sort_values(by='foreign_gross', ascending=False)
g.head(20)

# %%
#Checking for more misreported foreign gross
g.tail(20)

# %% [markdown]
# ### Foreign Gross values for some blockbusters are obviously misreported. Analysis will focus on domestic markets, as foreign gross values cannot be verified/trusted.

# %%
#domestic gross per title
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(20,8))

x1 = f['title'][:10]
y1 = f['domestic_gross'][:10]
ax1.bar(x1, y1)
ax1.tick_params(axis='x', rotation=90)
ax1.set_xlabel("Movie Title")
ax1.set_ylabel("Domestic Gross (hundreds of millions)")
ax1.set_title("Domestic Gross per Movie")


#Domestic gross per studio
dfm3 = df_gross.groupby(['studio']).domestic_gross.sum().reset_index().sort_values(by='domestic_gross', ascending=False)


x2 = dfm3.studio[:10]
y2 = dfm3.domestic_gross[:10]
ax2.bar(x2, y2)
ax2.tick_params(axis='x', rotation=90)
ax2.set_xlabel('Studio')
ax2.set_ylabel('Domestic Gross (tens of billions)')
ax2.set_title('Top 10 Highest Domestic Grossing Studios ')

#domestic gross for studios with most films
x = ['Uni.', 'Fox', 'WB', 'Sony', 'BV', 'Par.', 'LGF', 'Wein.', 'IFC', 'SPC']


x3 = d['studio']
y3 = d['domestic_gross']
ax3.bar(x3, y3)
ax3.tick_params(axis='x', rotation=90)
ax3.set_xlabel("Studio")
ax3.set_ylabel("Domestic Gross (tens of billions)")
ax3.set_title('Total Domestic Gross for Studio with Most Films')

fig.tight_layout()

# %%
#top 10 domestic gross studios
